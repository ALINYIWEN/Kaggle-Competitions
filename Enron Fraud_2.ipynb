# %% [markdown]
# ## Enron Fraud Dataset 安隆公司詐欺案資料集
# - 安隆公司曾是一間能源公司，2001 年破產前是世界上最大的電力、天然氣及電信公司之一。擁有上千億資產的公司於 2002 年竟然在短短幾周內宣告破產，才揭露其財報在多年以來均是造假的醜聞。在本資料集中你將會扮演偵探的角色，透過高層經理人內部的 mail 來往的情報以及薪資、股票等財務特徵，訓練出一個機器學習模型來幫忙你找到可疑的詐欺犯罪者是誰
#
# ### 評估
# - 兩個 column，分別為員工姓名 (name)、嫌犯的預測機率值 (poi)
# - 評估指標 AOC
# - 輸出是犯罪者的機率並儲存為.csv檔為結果上傳。

# %%
# 事前準備
import os
import numpy as np          # 資料處理分析工具
import pandas as pd         # 資料處理分析工具
from scipy import stats     # 統計函式庫
from scipy.stats import norm, skew
from collections import Counter # counter是字典，用來計數，key是要計數的item，value儲存的是個數
from sklearn.preprocessing import LabelEncoder # 用於特徵提取, 將數值資料轉為離散
from sklearn.preprocessing import MinMaxScaler

# 匯入必要的函式庫
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# 資料視覺化
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette() # 生成各種顏色
sns.set_style('darkgrid') # 設置主題：darkgrid、whitegrid、dark、white、ticks
# 設定展示欄位最大值
pd.set_option('display.max_row', 200) 
pd.set_option('display.max_columns', 100) 

# 忽略警告
import warnings
warnings.filterwarnings("ignore")

# %%
# 載入訓練資料集
train_data = pd.read_csv('./data/Enron Fraud/train_data.csv')
train_data.head(5)
# Out:
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2            SHELBY REX   200000.0                NaN          -4167.0
# 3      KOPPER MICHAEL J   800000.0                NaN              NaN
# 4  CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            NaN            ken.rice@enron.com               19794175.0
# 1            NaN       jeff.skilling@enron.com               19250000.0
# 2            NaN          rex.shelby@enron.com                1624396.0
# 3            NaN      michael.kopper@enron.com                      NaN
# 4            NaN  christopher.calger@enron.com                      NaN
#
#    expenses  from_messages  from_poi_to_this_person  from_this_person_to_poi  \
# 0   46950.0           18.0                     42.0                      4.0
# 1   29336.0          108.0                     88.0                     30.0
# 2   22884.0           39.0                     13.0                     14.0
# 3  118134.0            NaN                      NaN                      NaN
# 4   35818.0          144.0                    199.0                     25.0
#
#    loan_advances  long_term_incentive      other   poi  restricted_stock  \
# 0            NaN            1617011.0   174839.0  True         2748364.0
# 1            NaN            1920000.0    22122.0  True         6843672.0
# 2            NaN                  NaN  1573324.0  True          869220.0
# 3            NaN             602671.0   907502.0  True          985032.0
# 4            NaN             375304.0      486.0  True          126027.0
#
#    restricted_stock_deferred     salary  shared_receipt_with_poi  to_messages  \
# 0                        NaN   420636.0                    864.0        905.0
# 1                        NaN  1111258.0                   2042.0       3627.0
# 2                        NaN   211844.0                     91.0        225.0
# 3                        NaN   224305.0                      NaN          NaN
# 4                        NaN   240189.0                   2188.0       2598.0
#
#    total_payments  total_stock_value
# 0        505050.0         22542539.0
# 1       8682716.0         26093672.0
# 2       2003885.0          2493616.0
# 3       2652612.0           985032.0
# 4       1639297.0           126027.0

# %%
# 載入測試資料集
test_features = pd.read_csv('./data/Enron Fraud/test_features.csv')
test_features.head(5)
# Out:
#                  name      bonus  deferral_payments  deferred_income  \
# 0    BELDEN TIMOTHY N  5249999.0          2144013.0       -2334434.0
# 1  BOWEN JR RAYMOND M  1350000.0                NaN           -833.0
# 2      HANNON KEVIN P  1500000.0                NaN       -3117011.0
# 3    DELAINEY DAVID W  3000000.0                NaN              NaN
# 4    CAUSEY RICHARD A  1000000.0                NaN        -235000.0
#
#    director_fees             email_address  exercised_stock_options  expenses  \
# 0            NaN      tim.belden@enron.com                 953136.0   17355.0
# 1            NaN   raymond.bowen@enron.com                      NaN   65907.0
# 2            NaN    kevin.hannon@enron.com                5538001.0   34039.0
# 3            NaN  david.delainey@enron.com                2291113.0   86174.0
# 4            NaN  richard.causey@enron.com                      NaN   30674.0
#
#    from_messages  from_poi_to_this_person  from_this_person_to_poi  \
# 0          484.0                    228.0                    108.0
# 1           27.0                    140.0                     15.0
# 2           32.0                     32.0                     21.0
# 3         3069.0                     66.0                    609.0
# 4           49.0                     58.0                     12.0
#
#    loan_advances  long_term_incentive     other  restricted_stock  \
# 0            NaN                  NaN  210698.0          157569.0
# 1            NaN             974293.0    1621.0          252055.0
# 2            NaN            1617011.0   11350.0          853064.0
# 3            NaN            1294981.0    1661.0         1323148.0
# 4            NaN             350000.0  307895.0         2502063.0
#
#    restricted_stock_deferred    salary  shared_receipt_with_poi  to_messages  \
# 0                        NaN  213999.0                   5521.0       7991.0
# 1                        NaN  278601.0                   1593.0       1858.0
# 2                        NaN  243293.0                   1035.0       1045.0
# 3                        NaN  365163.0                   2097.0       3093.0
# 4                        NaN  415189.0                   1585.0       1892.0
#
#    total_payments  total_stock_value
# 0       5501630.0          1110705.0
# 1       2669589.0           252055.0
# 2        288682.0          6391065.0
# 3       4747979.0          3614261.0
# 4       1868758.0          2502063.0

# %% [markdown]
# #### 觀察資料
# - 發現只有name與email是字串
# - poi為布林值

# %%
# 確認資料特徵類型
print(f'train_data dtypes:\n{train_data.dtypes}')
print(f'\ntrain_data shape: {train_data.shape}')
print(f'\ntest_features shape: {test_features.shape}')
# Out:
# train_data dtypes:
# name                          object
# bonus                        float64
# deferral_payments            float64
# deferred_income              float64
# director_fees                float64
# email_address                 object
# exercised_stock_options      float64
# expenses                     float64
# from_messages                float64
# from_poi_to_this_person      float64
# from_this_person_to_poi      float64
# loan_advances                float64
# long_term_incentive          float64
# other                        float64
# poi                             bool
# restricted_stock             float64
# restricted_stock_deferred    float64
# salary                       float64
# shared_receipt_with_poi      float64
# to_messages                  float64
# total_payments               float64
# total_stock_value            float64
# dtype: object
#
# train_data shape: (113, 22)
#
# test_features shape: (33, 21)

# %% [markdown]
# #### 分析目標
# - test資料集比起train資料集少了poi這個欄位，
# - 此專案是藉由mail來往的情報以及薪資、股票等財務特徵來預測犯罪者 poi，True表示是，False表示否。
#
# #### 數據清洗
# - 移除不能用的資料

# %%
# 觀察哪些人的缺失值太多的人 例如大於18的，直接將其刪除
nan_index = []
for idx in train_data.index:
    if train_data.iloc[idx, :].isnull().sum()>17:
        nan_index.append(idx)
train_data.iloc[nan_index]
# Out:
#                               name  bonus  deferral_payments  deferred_income  \
# 17                    WROBEL BRUCE    NaN                NaN              NaN
# 30                  WHALEY DAVID A    NaN                NaN              NaN
# 65   THE TRAVEL AGENCY IN THE PARK    NaN                NaN              NaN
# 79                   GRAMM WENDY L    NaN                NaN              NaN
# 107              LOCKHART EUGENE E    NaN                NaN              NaN
#
#      director_fees email_address  exercised_stock_options  expenses  \
# 17             NaN           NaN                 139130.0       NaN
# 30             NaN           NaN                  98718.0       NaN
# 65             NaN           NaN                      NaN       NaN
# 79        119292.0           NaN                      NaN       NaN
# 107            NaN           NaN                      NaN       NaN
#
#      from_messages  from_poi_to_this_person  from_this_person_to_poi  \
# 17             NaN                      NaN                      NaN
# 30             NaN                      NaN                      NaN
# 65             NaN                      NaN                      NaN
# 79             NaN                      NaN                      NaN
# 107            NaN                      NaN                      NaN
#
#      loan_advances  long_term_incentive     other    poi  restricted_stock  \
# 17             NaN                  NaN       NaN  False               NaN
# 30             NaN                  NaN       NaN  False               NaN
# 65             NaN                  NaN  362096.0  False               NaN
# 79             NaN                  NaN       NaN  False               NaN
# 107            NaN                  NaN       NaN  False               NaN
#
#      restricted_stock_deferred  salary  shared_receipt_with_poi  to_messages  \
# 17                         NaN     NaN                      NaN          NaN
# 30                         NaN     NaN                      NaN          NaN
# 65                         NaN     NaN                      NaN          NaN
# 79                         NaN     NaN                      NaN          NaN
# 107                        NaN     NaN                      NaN          NaN
#
#      total_payments  total_stock_value
# 17              NaN           139130.0
# 30              NaN            98718.0
# 65         362096.0                NaN
# 79         119292.0                NaN
# 107             NaN                NaN

# %%
# 觀察資料後發現一個看起來不像人名，另一個則是全都是 NAN，將他們刪除
train_data = train_data[(train_data['name'] != "THE TRAVEL AGENCY IN THE PARK") & (train_data['name'] != "LOCKHART EUGENE E")]

# %% [markdown]
# #### 離群值檢測

# %%
# 建立異常值index陣列
outlier_indices = []

# 計算每個特徵的四分位數
for column in train_data.columns:
    if column in ['name','email_address','poi']:
        continue # continue：強制跳出 ❮本次❯ 迴圈，繼續進入下一圈
    Q1 = train_data.loc[train_data[column].notna(), column].quantile(0.25) # 計算第一四分位數
    Q3 = train_data.loc[train_data[column].notna(), column].quantile(0.75) # 計算第三四分位數
    
    # 四分位數間距（IQR）是第一個四分位數與第三個四分位數之間的差值, 用於檢測異常值
    IQR = Q3 - Q1
    
    # 將 1.5 x（IQR）添加到第三个四分位数。任何大于此的数字都是可疑的异常值。
    outlier_step = 1.5 * IQR
    
    # 取得是異常值的 index
    outlier_index = train_data[(train_data[column] < Q1 -outlier_step) | 
                               (train_data[column] > Q3 + outlier_step)].index
    
    # extend方法只能加入串列，不可以是元素。它會把串列中的元素做為個別元素加進串列裡
    outlier_indices.extend(outlier_index)
    
# 選擇包含超過n個異常值的觀察
outlier_indices = dict(Counter(outlier_indices))           # 將異常值的資料轉為字典
outlier_counts = pd.DataFrame.from_dict(
    outlier_indices, orient = 'index', columns=['counts']) # 將字典轉回dataframe形式
outlier_data = train_data.loc[outlier_indices.keys()]       # 取得異常值字典的 key
outlier_data = pd.concat([outlier_counts, outlier_data], axis = 1) # 將異常值計數與異常資料合併
outlier_data.sort_values(by = ['counts'], ascending = False) # 觀察
# Out:
#      counts                    name      bonus  deferral_payments  \
# 8         8           LAY KENNETH L  7000000.0           202911.0
# 1         7      SKILLING JEFFREY K  5600000.0                NaN
# 33        7         LAVORATO JOHN J  8000000.0                NaN
# 47        7      WHALLEY LAWRENCE G  3000000.0                NaN
# 58        6           BAXTER JOHN C  1200000.0          1295738.0
# 26        5          KITCHEN LOUISE  3100000.0                NaN
# 0         5          RICE KENNETH D  1750000.0                NaN
# 87        5           KEAN STEVEN J  1000000.0                NaN
# 14        4         ALLEN PHILLIP K  4175000.0          2869717.0
# 75        4      SHANKMAN JEFFREY A  2000000.0                NaN
# 78        4               PAI LOU L  1000000.0                NaN
# 112       4       SHAPIRO RICHARD S   650000.0                NaN
# 71        3       WHITE JR THOMAS E   450000.0                NaN
# 42        3         MARTIN AMANDA K        NaN            85430.0
# 12        3         FASTOW ANDREW S  1300000.0                NaN
# 86        3         IZZO LAWRENCE L        NaN                NaN
# 63        3            BECK SALLY W   700000.0                NaN
# 6         3          YEAGER F SCOTT        NaN                NaN
# 21        3      OVERDYKE JR JERE C        NaN                NaN
# 59        2           BUY RICHARD B   900000.0           649584.0
# 52        2     MCCONNELL MICHAEL S  1100000.0                NaN
# 29        2     KAMINSKI WINCENTY J   400000.0                NaN
# 37        2         REDMOND BRIAN L        NaN                NaN
# 105       2  CHRISTODOULOU DIOMEDES        NaN                NaN
# 90        2     DIMICHELE RICHARD G  1000000.0                NaN
# 45        2          ELLIOTT STEVEN   350000.0                NaN
# 5         2            HIRKO JOSEPH        NaN            10259.0
# 35        2         URQUHART JOHN A        NaN                NaN
# 68        2         HAEDICKE MARK E  1150000.0          2157527.0
# 44        1             GRAY RODNEY        NaN            93585.0
# 40        1      BAZELIDES PHILIP J        NaN           684694.0
# 111       1            HAUG DAVID L        NaN                NaN
# 2         1              SHELBY REX   200000.0                NaN
# 85        1      WESTFAHL RICHARD K        NaN                NaN
# 95        1      BANNANTINE JAMES M        NaN                NaN
# 110       1        PICKERING MARK R   300000.0                NaN
# 3         1        KOPPER MICHAEL J   800000.0                NaN
# 10        1           KOENIG MARK E   700000.0                NaN
# 49        1           MULLER MARK S  1100000.0           842924.0
# 48        1           ECHOLS JOHN B   200000.0                NaN
# 36        1        DIETRICH JANET R   600000.0                NaN
# 7         1          COLWELL WESLEY  1200000.0            27610.0
# 39        1     HAYSLETT RODERICK J        NaN                NaN
# 83        1        MCCLELLAN GEORGE   900000.0                NaN
# 9         1         GLISAN JR BEN F   600000.0                NaN
# 50        1           BELFER ROBERT        NaN          -102500.0
# 27        1          POWERS WILLIAM        NaN                NaN
# 77        1         HUMPHREY GENE E        NaN          2964506.0
# 69        1       WALLS JR ROBERT H   850000.0                NaN
#
#      deferred_income  director_fees                     email_address  \
# 8          -300000.0            NaN             kenneth.lay@enron.com
# 1                NaN            NaN           jeff.skilling@enron.com
# 33               NaN            NaN           john.lavorato@enron.com
# 47               NaN            NaN            greg.whalley@enron.com
# 58        -1386055.0            NaN                               NaN
# 26               NaN            NaN          louise.kitchen@enron.com
# 0         -3504386.0            NaN                ken.rice@enron.com
# 87               NaN            NaN             steven.kean@enron.com
# 14        -3081055.0            NaN           phillip.allen@enron.com
# 75               NaN            NaN        jeffrey.shankman@enron.com
# 78               NaN            NaN                 lou.pai@enron.com
# 112              NaN            NaN         richard.shapiro@enron.com
# 71               NaN            NaN            thomas.white@enron.com
# 42               NaN            NaN               a..martin@enron.com
# 12        -1386055.0            NaN           andrew.fastow@enron.com
# 86               NaN            NaN              larry.izzo@enron.com
# 63               NaN            NaN              sally.beck@enron.com
# 6                NaN            NaN            scott.yeager@enron.com
# 21               NaN            NaN           jere.overdyke@enron.com
# 59         -694862.0            NaN                rick.buy@enron.com
# 52               NaN            NaN          mike.mcconnell@enron.com
# 29               NaN            NaN          vince.kaminski@enron.com
# 37               NaN            NaN           brian.redmond@enron.com
# 105              NaN            NaN  diomedes.christodoulou@enron.com
# 90               NaN            NaN       richard.dimichele@enron.com
# 45         -400729.0            NaN          steven.elliott@enron.com
# 5                NaN            NaN               joe.hirko@enron.com
# 35          -36666.0        36666.0                               NaN
# 68         -934484.0            NaN           mark.haedicke@enron.com
# 44               NaN            NaN                               NaN
# 40               NaN            NaN                               NaN
# 111              NaN            NaN              david.haug@enron.com
# 2            -4167.0            NaN              rex.shelby@enron.com
# 85          -10800.0            NaN           dick.westfahl@enron.com
# 95           -5104.0            NaN        james.bannantine@enron.com
# 110              NaN            NaN          mark.pickering@enron.com
# 3                NaN            NaN          michael.kopper@enron.com
# 10               NaN            NaN             mark.koenig@enron.com
# 49         -719000.0            NaN               s..muller@enron.com
# 48               NaN            NaN             john.echols@enron.com
# 36               NaN            NaN          janet.dietrich@enron.com
# 7          -144062.0            NaN             wes.colwell@enron.com
# 39               NaN            NaN            rod.hayslett@enron.com
# 83         -125000.0            NaN        george.mcclellan@enron.com
# 9                NaN            NaN              ben.glisan@enron.com
# 50               NaN         3285.0                               NaN
# 27          -17500.0        17500.0              ken.powers@enron.com
# 77               NaN            NaN           gene.humphrey@enron.com
# 69               NaN            NaN               rob.walls@enron.com
#
#      exercised_stock_options  expenses  from_messages  \
# 8                 34348384.0   99832.0           36.0
# 1                 19250000.0   29336.0          108.0
# 33                 4158995.0   49537.0         2585.0
# 47                 3282960.0   57838.0          556.0
# 58                 6680544.0   11200.0            NaN
# 26                   81042.0    5774.0         1728.0
# 0                 19794175.0   46950.0           18.0
# 87                 2022048.0   41953.0         6759.0
# 14                 1729541.0   13868.0         2195.0
# 75                 1441898.0  178979.0         2681.0
# 78                15364167.0   32047.0            NaN
# 112                 607837.0  137767.0         1215.0
# 71                 1297049.0   81353.0            NaN
# 42                 2070306.0    8211.0          230.0
# 12                       NaN   55921.0            NaN
# 86                 2165172.0   28093.0           19.0
# 63                       NaN   37172.0         4343.0
# 6                  8308552.0   53947.0            NaN
# 21                 5266578.0   18834.0            NaN
# 59                 2542813.0       NaN         1053.0
# 52                 1623010.0   81364.0         2742.0
# 29                  850010.0   83585.0        14368.0
# 37                 7509039.0   14689.0          221.0
# 105                5127155.0       NaN            NaN
# 90                 8191755.0   35812.0            NaN
# 45                 4890344.0   78552.0            NaN
# 5                 30766064.0   77978.0            NaN
# 35                       NaN  228656.0            NaN
# 68                  608750.0   76169.0         1941.0
# 44                       NaN       NaN            NaN
# 40                 1599641.0       NaN            NaN
# 111                      NaN     475.0           19.0
# 2                  1624396.0   22884.0           39.0
# 85                       NaN   51870.0            NaN
# 95                 4046157.0   56301.0           29.0
# 110                  28798.0   31653.0           67.0
# 3                        NaN  118134.0            NaN
# 10                  671737.0  127017.0           61.0
# 49                 1056320.0       NaN           16.0
# 48                  601438.0   21530.0            NaN
# 36                 1550019.0    3475.0           63.0
# 7                        NaN   16514.0           40.0
# 39                       NaN       NaN         1061.0
# 83                  506765.0  228763.0           49.0
# 9                   384728.0  125978.0           16.0
# 50                    3285.0       NaN            NaN
# 27                       NaN       NaN           26.0
# 77                 2282768.0    4994.0           17.0
# 69                 4346544.0   50936.0          146.0
#
#      from_poi_to_this_person  from_this_person_to_poi  loan_advances  \
# 8                      123.0                     16.0     81525000.0
# 1                       88.0                     30.0            NaN
# 33                     528.0                    411.0            NaN
# 47                     186.0                     24.0            NaN
# 58                       NaN                      NaN            NaN
# 26                     251.0                    194.0            NaN
# 0                       42.0                      4.0            NaN
# 87                     140.0                    387.0            NaN
# 14                      47.0                     65.0            NaN
# 75                      94.0                     83.0            NaN
# 78                       NaN                      NaN            NaN
# 112                     74.0                     65.0            NaN
# 71                       NaN                      NaN            NaN
# 42                       8.0                      0.0            NaN
# 12                       NaN                      NaN            NaN
# 86                      28.0                      5.0            NaN
# 63                     144.0                    386.0            NaN
# 6                        NaN                      NaN            NaN
# 21                       NaN                      NaN            NaN
# 59                     156.0                     71.0            NaN
# 52                      92.0                    194.0            NaN
# 29                      41.0                    171.0            NaN
# 37                     204.0                     49.0            NaN
# 105                      NaN                      NaN            NaN
# 90                       NaN                      NaN            NaN
# 45                       NaN                      NaN            NaN
# 5                        NaN                      NaN            NaN
# 35                       NaN                      NaN            NaN
# 68                     180.0                     61.0            NaN
# 44                       NaN                      NaN            NaN
# 40                       NaN                      NaN            NaN
# 111                      4.0                      7.0            NaN
# 2                       13.0                     14.0            NaN
# 85                       NaN                      NaN            NaN
# 95                      39.0                      0.0            NaN
# 110                      7.0                      0.0       400000.0
# 3                        NaN                      NaN            NaN
# 10                      53.0                     15.0            NaN
# 49                      12.0                      0.0            NaN
# 48                       NaN                      NaN            NaN
# 36                     305.0                     14.0            NaN
# 7                      240.0                     11.0            NaN
# 39                      35.0                     38.0            NaN
# 83                      52.0                      0.0            NaN
# 9                       52.0                      6.0            NaN
# 50                       NaN                      NaN            NaN
# 27                       0.0                      0.0            NaN
# 77                      10.0                     17.0            NaN
# 69                      17.0                      0.0            NaN
#
#      long_term_incentive       other    poi  restricted_stock  \
# 8              3600000.0  10359729.0   True        14761694.0
# 1              1920000.0     22122.0   True         6843672.0
# 33             2035380.0      1552.0  False         1008149.0
# 47              808346.0    301026.0  False         2796177.0
# 58             1586055.0   2660303.0  False         3942714.0
# 26                   NaN     93925.0  False          466101.0
# 0              1617011.0    174839.0   True         2748364.0
# 87              300000.0      1231.0  False         4131594.0
# 14              304805.0       152.0  False          126027.0
# 75              554422.0      1191.0  False          630137.0
# 78                   NaN   1829457.0  False         8453763.0
# 112                  NaN       705.0  False          379164.0
# 71                   NaN   1085463.0  False        13847074.0
# 42             5145434.0   2818454.0  False               NaN
# 12             1736055.0    277464.0   True         1794412.0
# 86              312500.0   1553729.0  False         3654808.0
# 63                   NaN       566.0  False          126027.0
# 6                    NaN    147950.0   True         3576206.0
# 21              135836.0       176.0  False         2041016.0
# 59              769862.0    400572.0  False          901657.0
# 52              554422.0       540.0  False         1478269.0
# 29              323466.0      4669.0  False          126027.0
# 37                   NaN         NaN  False          381285.0
# 105                  NaN         NaN  False          950730.0
# 90              694862.0    374689.0  False          126027.0
# 45                   NaN     12961.0  False         1788391.0
# 5                    NaN      2856.0   True               NaN
# 35                   NaN         NaN  False               NaN
# 68              983346.0     52382.0  False          524169.0
# 44              365625.0    680833.0  False               NaN
# 40               93750.0       874.0  False               NaN
# 111                  NaN         NaN  False         2217299.0
# 2                    NaN   1573324.0   True          869220.0
# 85              256191.0    401130.0  False          384930.0
# 95                   NaN    864523.0  False         1757552.0
# 110                  NaN         NaN  False               NaN
# 3               602671.0    907502.0   True          985032.0
# 10              300000.0    150458.0   True         1248318.0
# 49             1725545.0       947.0  False          360528.0
# 48             2234774.0     53775.0  False          407503.0
# 36              556416.0       473.0  False          315068.0
# 7                    NaN    101740.0   True          698242.0
# 39                   NaN         NaN  False          346663.0
# 83                   NaN     51587.0  False          441096.0
# 9                71023.0    200308.0   True          393818.0
# 50                   NaN         NaN  False               NaN
# 27                   NaN         NaN  False               NaN
# 77                   NaN         NaN  False               NaN
# 69              540751.0         2.0  False         1552453.0
#
#      restricted_stock_deferred     salary  shared_receipt_with_poi  \
# 8                          NaN  1072321.0                   2411.0
# 1                          NaN  1111258.0                   2042.0
# 33                         NaN   339288.0                   3962.0
# 47                         NaN   510364.0                   3920.0
# 58                         NaN   267102.0                      NaN
# 26                         NaN   271442.0                   3669.0
# 0                          NaN   420636.0                    864.0
# 87                         NaN   404338.0                   3639.0
# 14                   -126027.0   201955.0                   1407.0
# 75                         NaN   304110.0                   1730.0
# 78                         NaN   261879.0                      NaN
# 112                        NaN   269076.0                   4527.0
# 71                         NaN   317543.0                      NaN
# 42                         NaN   349487.0                    477.0
# 12                         NaN   440698.0                      NaN
# 86                         NaN    85274.0                    437.0
# 63                         NaN   231330.0                   2639.0
# 6                          NaN   158403.0                      NaN
# 21                         NaN    94941.0                      NaN
# 59                         NaN   330546.0                   2333.0
# 52                         NaN   365038.0                   2189.0
# 29                         NaN   275101.0                    583.0
# 37                         NaN    96840.0                   1063.0
# 105                        NaN        NaN                      NaN
# 90                         NaN   262788.0                      NaN
# 45                         NaN   170941.0                      NaN
# 5                          NaN        NaN                      NaN
# 35                         NaN        NaN                      NaN
# 68                   -329825.0   374125.0                   1847.0
# 44                         NaN     6615.0                      NaN
# 40                         NaN    80818.0                      NaN
# 111                        NaN        NaN                    471.0
# 2                          NaN   211844.0                     91.0
# 85                         NaN    63744.0                      NaN
# 95                   -560222.0      477.0                    465.0
# 110                        NaN   655037.0                    728.0
# 3                          NaN   224305.0                      NaN
# 10                         NaN   309946.0                   2271.0
# 49                         NaN   251654.0                    114.0
# 48                         NaN   182245.0                      NaN
# 36                         NaN   250100.0                   1902.0
# 7                          NaN   288542.0                   1132.0
# 39                         NaN        NaN                    571.0
# 83                         NaN   263413.0                   1469.0
# 9                          NaN   274975.0                    874.0
# 50                     44093.0        NaN                      NaN
# 27                         NaN        NaN                     12.0
# 77                         NaN   130724.0                    119.0
# 69                         NaN   357091.0                    215.0
#
#      to_messages  total_payments  total_stock_value
# 8         4273.0     103559793.0         49110078.0
# 1         3627.0       8682716.0         26093672.0
# 33        7259.0      10425757.0          5167144.0
# 47        6019.0       4677574.0          6079137.0
# 58           NaN       5634343.0         10623258.0
# 26        8305.0       3471141.0           547143.0
# 0          905.0        505050.0         22542539.0
# 87       12754.0       1747522.0          6153642.0
# 14        2902.0       4484442.0          1729541.0
# 75        3221.0       3038702.0          2072035.0
# 78           NaN       3123383.0         23817930.0
# 112      15149.0       1057548.0           987001.0
# 71           NaN       1934359.0         15144123.0
# 42        1522.0       8407016.0          2070306.0
# 12           NaN       2424083.0          1794412.0
# 86         496.0       1979596.0          5819980.0
# 63        7315.0        969068.0           126027.0
# 6            NaN        360300.0         11884758.0
# 21           NaN        249787.0          7307594.0
# 59        3523.0       2355702.0          3444470.0
# 52        3329.0       2101364.0          3101279.0
# 29        4607.0       1086821.0           976037.0
# 37        1671.0        111529.0          7890324.0
# 105          NaN             NaN          6077885.0
# 90           NaN       2368151.0          8317782.0
# 45           NaN        211725.0          6678735.0
# 5            NaN         91093.0         30766064.0
# 35           NaN        228656.0                NaN
# 68        4009.0       3859065.0           803094.0
# 44           NaN       1146658.0                NaN
# 40           NaN        860136.0          1599641.0
# 111        573.0           475.0          2217299.0
# 2          225.0       2003885.0          2493616.0
# 85           NaN        762135.0           384930.0
# 95         566.0        916197.0          5243487.0
# 110        898.0       1386690.0            28798.0
# 3            NaN       2652612.0           985032.0
# 10        2374.0       1587421.0          1920055.0
# 49         136.0       3202070.0          1416848.0
# 48           NaN       2692324.0          1008941.0
# 36        2572.0       1410464.0          1865087.0
# 7         1758.0       1490344.0           698242.0
# 39        2649.0             NaN           346663.0
# 83        1744.0       1318763.0           947861.0
# 9          873.0       1272284.0           778546.0
# 50           NaN        102500.0           -44093.0
# 27         653.0             NaN                NaN
# 77         128.0       3100224.0          2282768.0
# 69         671.0       1798780.0          5898997.0

# %%
# 去除大於四個離群值的資料
outlier_drop = list(key for key, value in outlier_indices.items() if value >=4) # 取得index
print("異常值過多的index: " + str(outlier_drop))
train_data = train_data.drop(outlier_drop, axis = 0).reset_index(drop=True) # drop=True可以去除index那一column
train_data
# Out:
# 異常值過多的index: [1, 8, 14, 26, 33, 47, 75, 0, 58, 78, 112, 87]
#                            name      bonus  deferral_payments  \
# 0                    SHELBY REX   200000.0                NaN
# 1              KOPPER MICHAEL J   800000.0                NaN
# 2          CALGER CHRISTOPHER F  1250000.0                NaN
# 3                  HIRKO JOSEPH        NaN            10259.0
# 4                YEAGER F SCOTT        NaN                NaN
# 5                COLWELL WESLEY  1200000.0            27610.0
# 6               GLISAN JR BEN F   600000.0                NaN
# 7                 KOENIG MARK E   700000.0                NaN
# 8                RIEKER PAULA H   700000.0           214678.0
# 9               FASTOW ANDREW S  1300000.0                NaN
# 10                  GOLD JOSEPH   750000.0                NaN
# 11            BLACHMAN JEREMY M   850000.0                NaN
# 12                GAHN ROBERT S   509870.0            73122.0
# 13                 WROBEL BRUCE        NaN                NaN
# 14         CUMBERLAND MICHAEL S   325000.0                NaN
# 15                LEFF DANIEL P  1000000.0                NaN
# 16              THORN TERENCE H        NaN            16586.0
# 17           OVERDYKE JR JERE C        NaN                NaN
# 18            BUCHANAN HAROLD G   500000.0                NaN
# 19             MCDONALD REBECCA        NaN                NaN
# 20             CORDES WILLIAM R        NaN                NaN
# 21           GATHMANN WILLIAM D        NaN                NaN
# 22               POWERS WILLIAM        NaN                NaN
# 23                 DODSON KEITH    70000.0                NaN
# 24          KAMINSKI WINCENTY J   400000.0                NaN
# 25               WHALEY DAVID A        NaN                NaN
# 26         BERGSIEKER RICHARD P   250000.0                NaN
# 27              DURAN WILLIAM D   750000.0                NaN
# 28             DEFFNER JOSEPH M   600000.0                NaN
# 29              URQUHART JOHN A        NaN                NaN
# 30             DIETRICH JANET R   600000.0                NaN
# 31              REDMOND BRIAN L        NaN                NaN
# 32      PEREIRA PAULO V. FERRAZ        NaN                NaN
# 33          HAYSLETT RODERICK J        NaN                NaN
# 34           BAZELIDES PHILIP J        NaN           684694.0
# 35            LEMAISTRE CHARLES        NaN                NaN
# 36              MARTIN AMANDA K        NaN            85430.0
# 37                      FOY JOE        NaN           181755.0
# 38                  GRAY RODNEY        NaN            93585.0
# 39               ELLIOTT STEVEN   350000.0                NaN
# 40               BUTTS ROBERT H   750000.0                NaN
# 41                ECHOLS JOHN B   200000.0                NaN
# 42                MULLER MARK S  1100000.0           842924.0
# 43                BELFER ROBERT        NaN          -102500.0
# 44              GARLAND C KEVIN   850000.0                NaN
# 45          MCCONNELL MICHAEL S  1100000.0                NaN
# 46           TILNEY ELIZABETH A   300000.0                NaN
# 47                 SUNDE MARTIN   700000.0                NaN
# 48              BERBERIAN DAVID        NaN                NaN
# 49           BLAKE JR. NORMAN P        NaN                NaN
# 50              PIPER GREGORY F   400000.0          1130036.0
# 51                BUY RICHARD B   900000.0           649584.0
# 52                 FOWLER PEGGY        NaN                NaN
# 53              LOWRY CHARLES P        NaN                NaN
# 54            SCRIMSHAW MATTHEW        NaN                NaN
# 55                 BECK SALLY W   700000.0                NaN
# 56              MORAN MICHAEL P        NaN                NaN
# 57                WASAFF GEORGE   325000.0           831299.0
# 58             HERMANN ROBERT J   700000.0                NaN
# 59              HAEDICKE MARK E  1150000.0          2157527.0
# 60            WALLS JR ROBERT H   850000.0                NaN
# 61                  GILLIS JOHN        NaN                NaN
# 62            WHITE JR THOMAS E   450000.0                NaN
# 63              JAEDICKE ROBERT        NaN                NaN
# 64        WINOKUR JR. HERBERT S        NaN                NaN
# 65              MENDELSOHN JOHN        NaN                NaN
# 66                  FUGH JOHN L        NaN            50591.0
# 67              HUMPHREY GENE E        NaN          2964506.0
# 68                GRAMM WENDY L        NaN                NaN
# 69                OLSON CINDY K   750000.0            77716.0
# 70            TAYLOR MITCHELL S   600000.0           227449.0
# 71               HUGHES JAMES A        NaN                NaN
# 72             MCCLELLAN GEORGE   900000.0                NaN
# 73                DUNCAN JOHN H        NaN                NaN
# 74           WESTFAHL RICHARD K        NaN                NaN
# 75              IZZO LAWRENCE L        NaN                NaN
# 76  SULLIVAN-SHAKLOVITZ COLLEEN   100000.0           181993.0
# 77             FITZGERALD JAY L   350000.0                NaN
# 78          DIMICHELE RICHARD G  1000000.0                NaN
# 79               UMANOFF ADAM S   788750.0                NaN
# 80                BADUM JAMES P        NaN           178980.0
# 81               HAYES ROBERT E        NaN             7961.0
# 82              CLINE KENNETH W        NaN                NaN
# 83           BANNANTINE JAMES M        NaN                NaN
# 84                    COX DAVID   800000.0                NaN
# 85             SHARP VICTORIA T   600000.0           187469.0
# 86                 SAVAGE FRANK        NaN                NaN
# 87                NOLES JAMES L        NaN           774401.0
# 88                 WAKEHAM JOHN        NaN                NaN
# 89              MCCARTY DANNY J        NaN                NaN
# 90               MURRAY JULIA H   400000.0                NaN
# 91             MEYER ROCKFORD G        NaN          1848227.0
# 92                    YEAP SOON        NaN                NaN
# 93       CHRISTODOULOU DIOMEDES        NaN                NaN
# 94           JACKSON CHARLENE R   250000.0                NaN
# 95                STABLER FRANK   500000.0                NaN
# 96                BROWN MICHAEL        NaN                NaN
# 97             PICKERING MARK R   300000.0                NaN
# 98                 HAUG DAVID L        NaN                NaN
#
#     deferred_income  director_fees                     email_address  \
# 0           -4167.0            NaN              rex.shelby@enron.com
# 1               NaN            NaN          michael.kopper@enron.com
# 2         -262500.0            NaN      christopher.calger@enron.com
# 3               NaN            NaN               joe.hirko@enron.com
# 4               NaN            NaN            scott.yeager@enron.com
# 5         -144062.0            NaN             wes.colwell@enron.com
# 6               NaN            NaN              ben.glisan@enron.com
# 7               NaN            NaN             mark.koenig@enron.com
# 8         -100000.0            NaN            paula.rieker@enron.com
# 9        -1386055.0            NaN           andrew.fastow@enron.com
# 10              NaN            NaN                joe.gold@enron.com
# 11              NaN            NaN         jeremy.blachman@enron.com
# 12          -1042.0            NaN                               NaN
# 13              NaN            NaN                               NaN
# 14              NaN            NaN                               NaN
# 15              NaN            NaN                dan.leff@enron.com
# 16              NaN            NaN           terence.thorn@enron.com
# 17              NaN            NaN           jere.overdyke@enron.com
# 18              NaN            NaN           john.buchanan@enron.com
# 19              NaN            NaN        rebecca.mcdonald@enron.com
# 20              NaN            NaN             bill.cordes@enron.com
# 21              NaN            NaN                               NaN
# 22         -17500.0        17500.0              ken.powers@enron.com
# 23              NaN            NaN            keith.dodson@enron.com
# 24              NaN            NaN          vince.kaminski@enron.com
# 25              NaN            NaN                               NaN
# 26        -485813.0            NaN         rick.bergsieker@enron.com
# 27              NaN            NaN                 w.duran@enron.com
# 28              NaN            NaN          joseph.deffner@enron.com
# 29         -36666.0        36666.0                               NaN
# 30              NaN            NaN          janet.dietrich@enron.com
# 31              NaN            NaN           brian.redmond@enron.com
# 32        -101250.0       101250.0                               NaN
# 33              NaN            NaN            rod.hayslett@enron.com
# 34              NaN            NaN                               NaN
# 35         -25000.0       112492.0                               NaN
# 36              NaN            NaN               a..martin@enron.com
# 37              NaN            NaN               tracy.foy@enron.com
# 38              NaN            NaN                               NaN
# 39        -400729.0            NaN          steven.elliott@enron.com
# 40         -75000.0            NaN               bob.butts@enron.com
# 41              NaN            NaN             john.echols@enron.com
# 42        -719000.0            NaN               s..muller@enron.com
# 43              NaN         3285.0                               NaN
# 44              NaN            NaN           kevin.garland@enron.com
# 45              NaN            NaN          mike.mcconnell@enron.com
# 46        -575000.0            NaN        elizabeth.tilney@enron.com
# 47              NaN            NaN             marty.sunde@enron.com
# 48              NaN            NaN         david.berberian@enron.com
# 49        -113784.0       113784.0                               NaN
# 50         -33333.0            NaN              greg.piper@enron.com
# 51        -694862.0            NaN                rick.buy@enron.com
# 52              NaN            NaN        kulvinder.fowler@enron.com
# 53              NaN            NaN                               NaN
# 54              NaN            NaN       matthew.scrimshaw@enron.com
# 55              NaN            NaN              sally.beck@enron.com
# 56              NaN            NaN           michael.moran@enron.com
# 57        -583325.0            NaN           george.wasaff@enron.com
# 58        -280000.0            NaN          robert.hermann@enron.com
# 59        -934484.0            NaN           mark.haedicke@enron.com
# 60              NaN            NaN               rob.walls@enron.com
# 61              NaN            NaN                               NaN
# 62              NaN            NaN            thomas.white@enron.com
# 63         -25000.0       108750.0                               NaN
# 64         -25000.0       108579.0                               NaN
# 65        -103750.0       103750.0                               NaN
# 66              NaN            NaN                               NaN
# 67              NaN            NaN           gene.humphrey@enron.com
# 68              NaN       119292.0                               NaN
# 69              NaN            NaN             cindy.olson@enron.com
# 70              NaN            NaN         mitchell.taylor@enron.com
# 71              NaN            NaN            james.hughes@enron.com
# 72        -125000.0            NaN        george.mcclellan@enron.com
# 73         -25000.0       102492.0                               NaN
# 74         -10800.0            NaN           dick.westfahl@enron.com
# 75              NaN            NaN              larry.izzo@enron.com
# 76              NaN            NaN                               NaN
# 77              NaN            NaN          jay.fitzgerald@enron.com
# 78              NaN            NaN       richard.dimichele@enron.com
# 79              NaN            NaN            adam.umanoff@enron.com
# 80              NaN            NaN                               NaN
# 81              NaN            NaN            robert.hayes@enron.com
# 82              NaN            NaN                               NaN
# 83          -5104.0            NaN        james.bannantine@enron.com
# 84         -41250.0            NaN                chip.cox@enron.com
# 85              NaN            NaN             vicki.sharp@enron.com
# 86        -121284.0       125034.0                               NaN
# 87              NaN            NaN                               NaN
# 88              NaN       109298.0                               NaN
# 89              NaN            NaN           danny.mccarty@enron.com
# 90              NaN            NaN            julia.murray@enron.com
# 91              NaN            NaN          rockford.meyer@enron.com
# 92              NaN            NaN                               NaN
# 93              NaN            NaN  diomedes.christodoulou@enron.com
# 94              NaN            NaN        charlene.jackson@enron.com
# 95              NaN            NaN           frank.stabler@enron.com
# 96              NaN            NaN           michael.brown@enron.com
# 97              NaN            NaN          mark.pickering@enron.com
# 98              NaN            NaN              david.haug@enron.com
#
#     exercised_stock_options  expenses  from_messages  from_poi_to_this_person  \
# 0                 1624396.0   22884.0           39.0                     13.0
# 1                       NaN  118134.0            NaN                      NaN
# 2                       NaN   35818.0          144.0                    199.0
# 3                30766064.0   77978.0            NaN                      NaN
# 4                 8308552.0   53947.0            NaN                      NaN
# 5                       NaN   16514.0           40.0                    240.0
# 6                  384728.0  125978.0           16.0                     52.0
# 7                  671737.0  127017.0           61.0                     53.0
# 8                 1635238.0   33271.0           82.0                     35.0
# 9                       NaN   55921.0            NaN                      NaN
# 10                 436515.0       NaN            NaN                      NaN
# 11                 765313.0   84208.0           14.0                     25.0
# 12                  83237.0   50080.0            NaN                      NaN
# 13                 139130.0       NaN            NaN                      NaN
# 14                      NaN   22344.0            NaN                      NaN
# 15                      NaN       NaN           63.0                     67.0
# 16                4452476.0   46145.0           41.0                      0.0
# 17                5266578.0   18834.0            NaN                      NaN
# 18                 825464.0     600.0          125.0                      0.0
# 19                 757301.0       NaN           13.0                     54.0
# 20                 651850.0       NaN           12.0                     10.0
# 21                1753766.0       NaN            NaN                      NaN
# 22                      NaN       NaN           26.0                      0.0
# 23                      NaN   28164.0           14.0                     10.0
# 24                 850010.0   83585.0        14368.0                     41.0
# 25                  98718.0       NaN            NaN                      NaN
# 26                      NaN   59175.0           59.0                      4.0
# 27                1451869.0   25785.0           12.0                    106.0
# 28                  17378.0   41626.0           74.0                    115.0
# 29                      NaN  228656.0            NaN                      NaN
# 30                1550019.0    3475.0           63.0                    305.0
# 31                7509039.0   14689.0          221.0                    204.0
# 32                      NaN   27942.0            NaN                      NaN
# 33                      NaN       NaN         1061.0                     35.0
# 34                1599641.0       NaN            NaN                      NaN
# 35                 412878.0       NaN            NaN                      NaN
# 36                2070306.0    8211.0          230.0                      8.0
# 37                 343434.0       NaN           13.0                      0.0
# 38                      NaN       NaN            NaN                      NaN
# 39                4890344.0   78552.0            NaN                      NaN
# 40                      NaN    9410.0            NaN                      NaN
# 41                 601438.0   21530.0            NaN                      NaN
# 42                1056320.0       NaN           16.0                     12.0
# 43                   3285.0       NaN            NaN                      NaN
# 44                 636246.0   48405.0           44.0                     10.0
# 45                1623010.0   81364.0         2742.0                     92.0
# 46                 591250.0       NaN           19.0                     10.0
# 47                      NaN       NaN           38.0                     37.0
# 48                1624396.0   11892.0            NaN                      NaN
# 49                      NaN    1279.0            NaN                      NaN
# 50                 880290.0   43057.0          222.0                     61.0
# 51                2542813.0       NaN         1053.0                    156.0
# 52                1324578.0       NaN           36.0                      0.0
# 53                 372205.0       NaN            NaN                      NaN
# 54                 759557.0       NaN            NaN                      NaN
# 55                      NaN   37172.0         4343.0                    144.0
# 56                  59539.0       NaN           19.0                      0.0
# 57                1668260.0       NaN           30.0                     22.0
# 58                 187500.0   48357.0            NaN                      NaN
# 59                 608750.0   76169.0         1941.0                    180.0
# 60                4346544.0   50936.0          146.0                     17.0
# 61                   9803.0       NaN            NaN                      NaN
# 62                1297049.0   81353.0            NaN                      NaN
# 63                 431750.0       NaN            NaN                      NaN
# 64                      NaN    1413.0            NaN                      NaN
# 65                      NaN     148.0            NaN                      NaN
# 66                 176378.0       NaN            NaN                      NaN
# 67                2282768.0    4994.0           17.0                     10.0
# 68                      NaN       NaN            NaN                      NaN
# 69                1637034.0   63791.0           52.0                     20.0
# 70                3181250.0       NaN           29.0                      0.0
# 71                 754966.0       NaN           34.0                     35.0
# 72                 506765.0  228763.0           49.0                     52.0
# 73                 371750.0       NaN            NaN                      NaN
# 74                      NaN   51870.0            NaN                      NaN
# 75                2165172.0   28093.0           19.0                     28.0
# 76                1362375.0       NaN            NaN                      NaN
# 77                 664461.0   23870.0           16.0                      1.0
# 78                8191755.0   35812.0            NaN                      NaN
# 79                      NaN   53122.0           18.0                     12.0
# 80                 257817.0    3486.0            NaN                      NaN
# 81                      NaN       NaN           12.0                     16.0
# 82                      NaN       NaN            NaN                      NaN
# 83                4046157.0   56301.0           29.0                     39.0
# 84                 117551.0   27861.0           33.0                      0.0
# 85                 281073.0  116337.0          136.0                     24.0
# 86                      NaN       NaN            NaN                      NaN
# 87                      NaN       NaN            NaN                      NaN
# 88                      NaN  103773.0            NaN                      NaN
# 89                 664375.0       NaN          215.0                     25.0
# 90                 400478.0   57580.0           45.0                     11.0
# 91                 493489.0       NaN           28.0                      0.0
# 92                 192758.0   55097.0            NaN                      NaN
# 93                5127155.0       NaN            NaN                      NaN
# 94                 185063.0   10181.0           56.0                     25.0
# 95                      NaN   16514.0            NaN                      NaN
# 96                      NaN   49288.0           41.0                     13.0
# 97                  28798.0   31653.0           67.0                      7.0
# 98                      NaN     475.0           19.0                      4.0
#
#     from_this_person_to_poi  loan_advances  long_term_incentive      other  \
# 0                      14.0            NaN                  NaN  1573324.0
# 1                       NaN            NaN             602671.0   907502.0
# 2                      25.0            NaN             375304.0      486.0
# 3                       NaN            NaN                  NaN     2856.0
# 4                       NaN            NaN                  NaN   147950.0
# 5                      11.0            NaN                  NaN   101740.0
# 6                       6.0            NaN              71023.0   200308.0
# 7                      15.0            NaN             300000.0   150458.0
# 8                      48.0            NaN                  NaN     1950.0
# 9                       NaN            NaN            1736055.0   277464.0
# 10                      NaN            NaN             304805.0   819288.0
# 11                      2.0            NaN             831809.0      272.0
# 12                      NaN            NaN                  NaN    76547.0
# 13                      NaN            NaN                  NaN        NaN
# 14                      NaN            NaN             275000.0      713.0
# 15                     14.0            NaN            1387399.0     3083.0
# 16                      0.0            NaN             200000.0   426629.0
# 17                      NaN            NaN             135836.0      176.0
# 18                      0.0            NaN             304805.0     1215.0
# 19                      1.0            NaN                  NaN        NaN
# 20                      0.0            NaN                  NaN        NaN
# 21                      NaN            NaN                  NaN        NaN
# 22                      0.0            NaN                  NaN        NaN
# 23                      3.0            NaN                  NaN      774.0
# 24                    171.0            NaN             323466.0     4669.0
# 25                      NaN            NaN                  NaN        NaN
# 26                      0.0            NaN             180250.0   427316.0
# 27                      3.0            NaN            1105218.0     1568.0
# 28                      4.0            NaN             335349.0    25553.0
# 29                      NaN            NaN                  NaN        NaN
# 30                     14.0            NaN             556416.0      473.0
# 31                     49.0            NaN                  NaN        NaN
# 32                      NaN            NaN                  NaN        NaN
# 33                     38.0            NaN                  NaN        NaN
# 34                      NaN            NaN              93750.0      874.0
# 35                      NaN            NaN                  NaN        NaN
# 36                      0.0            NaN            5145434.0  2818454.0
# 37                      0.0            NaN                  NaN        NaN
# 38                      NaN            NaN             365625.0   680833.0
# 39                      NaN            NaN                  NaN    12961.0
# 40                      NaN            NaN             175000.0   150656.0
# 41                      NaN            NaN            2234774.0    53775.0
# 42                      0.0            NaN            1725545.0      947.0
# 43                      NaN            NaN                  NaN        NaN
# 44                     27.0            NaN             375304.0    60814.0
# 45                    194.0            NaN             554422.0      540.0
# 46                     11.0            NaN             275000.0   152055.0
# 47                     13.0            NaN             476451.0   111122.0
# 48                      NaN            NaN                  NaN        NaN
# 49                      NaN            NaN                  NaN        NaN
# 50                     48.0            NaN                  NaN      778.0
# 51                     71.0            NaN             769862.0   400572.0
# 52                      0.0            NaN                  NaN        NaN
# 53                      NaN            NaN                  NaN        NaN
# 54                      NaN            NaN                  NaN        NaN
# 55                    386.0            NaN                  NaN      566.0
# 56                      0.0            NaN                  NaN        NaN
# 57                      7.0            NaN             200000.0     1425.0
# 58                      NaN            NaN             150000.0   416441.0
# 59                     61.0            NaN             983346.0    52382.0
# 60                      0.0            NaN             540751.0        2.0
# 61                      NaN            NaN                  NaN        NaN
# 62                      NaN            NaN                  NaN  1085463.0
# 63                      NaN            NaN                  NaN        NaN
# 64                      NaN            NaN                  NaN        NaN
# 65                      NaN            NaN                  NaN        NaN
# 66                      NaN            NaN                  NaN        NaN
# 67                     17.0            NaN                  NaN        NaN
# 68                      NaN            NaN                  NaN        NaN
# 69                     15.0            NaN             100000.0      972.0
# 70                      0.0            NaN                  NaN        NaN
# 71                      5.0            NaN                  NaN        NaN
# 72                      0.0            NaN                  NaN    51587.0
# 73                      NaN            NaN                  NaN        NaN
# 74                      NaN            NaN             256191.0   401130.0
# 75                      5.0            NaN             312500.0  1553729.0
# 76                      NaN            NaN             554422.0      162.0
# 77                      8.0            NaN             556416.0   285414.0
# 78                      NaN            NaN             694862.0   374689.0
# 79                      0.0            NaN                  NaN        NaN
# 80                      NaN            NaN                  NaN        NaN
# 81                      0.0            NaN                  NaN        NaN
# 82                      NaN            NaN                  NaN        NaN
# 83                      0.0            NaN                  NaN   864523.0
# 84                      4.0            NaN                  NaN      494.0
# 85                      6.0            NaN             422158.0     2401.0
# 86                      NaN            NaN                  NaN        NaN
# 87                      NaN            NaN                  NaN        NaN
# 88                      NaN            NaN                  NaN        NaN
# 89                      2.0            NaN                  NaN        NaN
# 90                      2.0            NaN             125000.0      330.0
# 91                      0.0            NaN                  NaN        NaN
# 92                      NaN            NaN                  NaN        NaN
# 93                      NaN            NaN                  NaN        NaN
# 94                     19.0            NaN                  NaN     2435.0
# 95                      NaN            NaN                  NaN   356071.0
# 96                      1.0            NaN                  NaN        NaN
# 97                      0.0       400000.0                  NaN        NaN
# 98                      7.0            NaN                  NaN        NaN
#
#       poi  restricted_stock  restricted_stock_deferred    salary  \
# 0    True          869220.0                        NaN  211844.0
# 1    True          985032.0                        NaN  224305.0
# 2    True          126027.0                        NaN  240189.0
# 3    True               NaN                        NaN       NaN
# 4    True         3576206.0                        NaN  158403.0
# 5    True          698242.0                        NaN  288542.0
# 6    True          393818.0                        NaN  274975.0
# 7    True         1248318.0                        NaN  309946.0
# 8    True          283649.0                        NaN  249201.0
# 9    True         1794412.0                        NaN  440698.0
# 10  False          441096.0                        NaN  272880.0
# 11  False          189041.0                        NaN  248546.0
# 12  False          235370.0                        NaN  192008.0
# 13  False               NaN                        NaN       NaN
# 14  False          207940.0                        NaN  184899.0
# 15  False          360528.0                        NaN  273746.0
# 16  False          365320.0                        NaN  222093.0
# 17  False         2041016.0                        NaN   94941.0
# 18  False          189041.0                        NaN  248017.0
# 19  False          934065.0                        NaN       NaN
# 20  False          386335.0                        NaN       NaN
# 21  False          264013.0                   -72419.0       NaN
# 22  False               NaN                        NaN       NaN
# 23  False               NaN                        NaN  221003.0
# 24  False          126027.0                        NaN  275101.0
# 25  False               NaN                        NaN       NaN
# 26  False          659249.0                        NaN  187922.0
# 27  False          189041.0                        NaN  210692.0
# 28  False          141833.0                        NaN  206121.0
# 29  False               NaN                        NaN       NaN
# 30  False          315068.0                        NaN  250100.0
# 31  False          381285.0                        NaN   96840.0
# 32  False               NaN                        NaN       NaN
# 33  False          346663.0                        NaN       NaN
# 34  False               NaN                        NaN   80818.0
# 35  False               NaN                        NaN       NaN
# 36  False               NaN                        NaN  349487.0
# 37  False               NaN                        NaN       NaN
# 38  False               NaN                        NaN    6615.0
# 39  False         1788391.0                        NaN  170941.0
# 40  False          417619.0                        NaN  261516.0
# 41  False          407503.0                        NaN  182245.0
# 42  False          360528.0                        NaN  251654.0
# 43  False               NaN                    44093.0       NaN
# 44  False          259907.0                        NaN  231946.0
# 45  False         1478269.0                        NaN  365038.0
# 46  False          576792.0                        NaN  247338.0
# 47  False          698920.0                        NaN  257486.0
# 48  False          869220.0                        NaN  216582.0
# 49  False               NaN                        NaN       NaN
# 50  False          409554.0                  -409554.0  197091.0
# 51  False          901657.0                        NaN  330546.0
# 52  False          560170.0                        NaN       NaN
# 53  False          153686.0                  -153686.0       NaN
# 54  False               NaN                        NaN       NaN
# 55  False          126027.0                        NaN  231330.0
# 56  False          161602.0                        NaN       NaN
# 57  False          388167.0                        NaN  259996.0
# 58  False          480632.0                        NaN  262663.0
# 59  False          524169.0                  -329825.0  374125.0
# 60  False         1552453.0                        NaN  357091.0
# 61  False           75838.0                        NaN       NaN
# 62  False        13847074.0                        NaN  317543.0
# 63  False           44093.0                   -44093.0       NaN
# 64  False               NaN                        NaN       NaN
# 65  False               NaN                        NaN       NaN
# 66  False               NaN                        NaN       NaN
# 67  False               NaN                        NaN  130724.0
# 68  False               NaN                        NaN       NaN
# 69  False          969729.0                        NaN  329078.0
# 70  False          563798.0                        NaN  265214.0
# 71  False          363428.0                        NaN       NaN
# 72  False          441096.0                        NaN  263413.0
# 73  False               NaN                        NaN       NaN
# 74  False          384930.0                        NaN   63744.0
# 75  False         3654808.0                        NaN   85274.0
# 76  False               NaN                        NaN  162779.0
# 77  False          956775.0                        NaN  199157.0
# 78  False          126027.0                        NaN  262788.0
# 79  False               NaN                        NaN  288589.0
# 80  False               NaN                        NaN       NaN
# 81  False          151418.0                        NaN       NaN
# 82  False          662086.0                  -472568.0       NaN
# 83  False         1757552.0                  -560222.0     477.0
# 84  False          378082.0                        NaN  314288.0
# 85  False          213063.0                        NaN  248146.0
# 86  False               NaN                        NaN       NaN
# 87  False          463261.0                   -94556.0       NaN
# 88  False               NaN                        NaN       NaN
# 89  False           94556.0                        NaN       NaN
# 90  False          196983.0                        NaN  229284.0
# 91  False          462384.0                        NaN       NaN
# 92  False               NaN                        NaN       NaN
# 93  False          950730.0                        NaN       NaN
# 94  False          540672.0                        NaN  288558.0
# 95  False          511734.0                        NaN  239502.0
# 96  False               NaN                        NaN       NaN
# 97  False               NaN                        NaN  655037.0
# 98  False         2217299.0                        NaN       NaN
#
#     shared_receipt_with_poi  to_messages  total_payments  total_stock_value
# 0                      91.0        225.0       2003885.0          2493616.0
# 1                       NaN          NaN       2652612.0           985032.0
# 2                    2188.0       2598.0       1639297.0           126027.0
# 3                       NaN          NaN         91093.0         30766064.0
# 4                       NaN          NaN        360300.0         11884758.0
# 5                    1132.0       1758.0       1490344.0           698242.0
# 6                     874.0        873.0       1272284.0           778546.0
# 7                    2271.0       2374.0       1587421.0          1920055.0
# 8                    1258.0       1328.0       1099100.0          1918887.0
# 9                       NaN          NaN       2424083.0          1794412.0
# 10                      NaN          NaN       2146973.0           877611.0
# 11                   2326.0       2475.0       2014835.0           954354.0
# 12                      NaN          NaN        900585.0           318607.0
# 13                      NaN          NaN             NaN           139130.0
# 14                      NaN          NaN        807956.0           207940.0
# 15                   2672.0       2822.0       2664228.0           360528.0
# 16                     73.0        266.0        911453.0          4817796.0
# 17                      NaN          NaN        249787.0          7307594.0
# 18                     23.0       1088.0       1054637.0          1014505.0
# 19                    720.0        894.0             NaN          1691366.0
# 20                     58.0        764.0             NaN          1038185.0
# 21                      NaN          NaN             NaN          1945360.0
# 22                     12.0        653.0             NaN                NaN
# 23                    114.0        176.0        319941.0                NaN
# 24                    583.0       4607.0       1086821.0           976037.0
# 25                      NaN          NaN             NaN            98718.0
# 26                    233.0        383.0        618850.0           659249.0
# 27                    599.0        904.0       2093263.0          1640910.0
# 28                    552.0        714.0       1208649.0           159211.0
# 29                      NaN          NaN        228656.0                NaN
# 30                   1902.0       2572.0       1410464.0          1865087.0
# 31                   1063.0       1671.0        111529.0          7890324.0
# 32                      NaN          NaN         27942.0                NaN
# 33                    571.0       2649.0             NaN           346663.0
# 34                      NaN          NaN        860136.0          1599641.0
# 35                      NaN          NaN         87492.0           412878.0
# 36                    477.0       1522.0       8407016.0          2070306.0
# 37                      2.0         57.0        181755.0           343434.0
# 38                      NaN          NaN       1146658.0                NaN
# 39                      NaN          NaN        211725.0          6678735.0
# 40                      NaN          NaN       1271582.0           417619.0
# 41                      NaN          NaN       2692324.0          1008941.0
# 42                    114.0        136.0       3202070.0          1416848.0
# 43                      NaN          NaN        102500.0           -44093.0
# 44                    178.0        209.0       1566469.0           896153.0
# 45                   2189.0       3329.0       2101364.0          3101279.0
# 46                    379.0        460.0        399393.0          1168042.0
# 47                   2565.0       2647.0       1545059.0           698920.0
# 48                      NaN          NaN        228474.0          2493616.0
# 49                      NaN          NaN          1279.0                NaN
# 50                    742.0       1238.0       1737629.0           880290.0
# 51                   2333.0       3523.0       2355702.0          3444470.0
# 52                     10.0        517.0             NaN          1884748.0
# 53                      NaN          NaN             NaN           372205.0
# 54                      NaN          NaN             NaN           759557.0
# 55                   2639.0       7315.0        969068.0           126027.0
# 56                    127.0        672.0             NaN           221141.0
# 57                    337.0        400.0       1034395.0          2056427.0
# 58                      NaN          NaN       1297461.0           668132.0
# 59                   1847.0       4009.0       3859065.0           803094.0
# 60                    215.0        671.0       1798780.0          5898997.0
# 61                      NaN          NaN             NaN            85641.0
# 62                      NaN          NaN       1934359.0         15144123.0
# 63                      NaN          NaN         83750.0           431750.0
# 64                      NaN          NaN         84992.0                NaN
# 65                      NaN          NaN           148.0                NaN
# 66                      NaN          NaN         50591.0           176378.0
# 67                    119.0        128.0       3100224.0          2282768.0
# 68                      NaN          NaN        119292.0                NaN
# 69                    856.0       1184.0       1321557.0          2606763.0
# 70                    300.0        533.0       1092663.0          3745048.0
# 71                    589.0        719.0             NaN          1118394.0
# 72                   1469.0       1744.0       1318763.0           947861.0
# 73                      NaN          NaN         77492.0           371750.0
# 74                      NaN          NaN        762135.0           384930.0
# 75                    437.0        496.0       1979596.0          5819980.0
# 76                      NaN          NaN        999356.0          1362375.0
# 77                    723.0        936.0       1414857.0          1621236.0
# 78                      NaN          NaN       2368151.0          8317782.0
# 79                     41.0        111.0       1130461.0                NaN
# 80                      NaN          NaN        182466.0           257817.0
# 81                     50.0        504.0          7961.0           151418.0
# 82                      NaN          NaN             NaN           189518.0
# 83                    465.0        566.0        916197.0          5243487.0
# 84                     71.0        102.0       1101393.0           495633.0
# 85                   2477.0       3136.0       1576511.0           494136.0
# 86                      NaN          NaN          3750.0                NaN
# 87                      NaN          NaN        774401.0           368705.0
# 88                      NaN          NaN        213071.0                NaN
# 89                    508.0       1433.0             NaN           758931.0
# 90                    395.0       2192.0        812194.0           597461.0
# 91                     22.0        232.0       1848227.0           955873.0
# 92                      NaN          NaN         55097.0           192758.0
# 93                      NaN          NaN             NaN          6077885.0
# 94                    117.0        258.0        551174.0           725735.0
# 95                      NaN          NaN       1112087.0           511734.0
# 96                    761.0       1486.0         49288.0                NaN
# 97                    728.0        898.0       1386690.0            28798.0
# 98                    471.0        573.0           475.0          2217299.0

# %% [markdown]
# #### 移除無法作為特徵的欄位
# - 由於姓名沒有職稱(Mr. Misss.等稱謂)，email也沒有特別之處，所以刪掉。

# %%
# 移除'name','email_address'
train_name = train_data['name']
train_email_address = train_data['email_address']
test_name = test_features['name']
test_email_address = test_features['email_address']

# 觀察移除欄位後的資料及尺寸
y_train = train_data['poi']
train_data = train_data.drop(['name','email_address','poi'], axis = 1) # 刪除指定column
test_features = test_features.drop(['name', 'email_address'], axis = 1)

print('train_data shape: '+str(train_data.shape))
print('y_train shape: '+str(y_train.shape))
print('test_features shape: '+str(test_features.shape))
# Out:
# train_data shape: (99, 19)
# y_train shape: (99,)
# test_features shape: (33, 19)

# %% [markdown]
# #### 偏態檢查
# - 去除偏態：若標準化後離群值比例過高或是平均值沒有代表性，就是資料不太像常態分佈、資料明顯偏一邊之類的XD，則可以透過去除偏態讓資料更接近常態分佈（左右對稱、中央更集中）
# - np.log1p 先做數據平滑處理 使其更加服從高斯分布

# %%
# 合併 train & test 資料集
X = pd.concat([train_data, test_features], ignore_index = True)

# 觀察欄位型態
print(f'\ndtypes of each columns:\n{X.dtypes}')
# 觀察空值數
print(f'\nnumbers of NaN:\n{X.isnull().sum()}')
# 觀察相異數
print(f'\nnumbers of nunique:\n{X.nunique()}')
# Out:
# dtypes of each columns:
# bonus                        float64
# deferral_payments            float64
# deferred_income              float64
# director_fees                float64
# exercised_stock_options      float64
# expenses                     float64
# from_messages                float64
# from_poi_to_this_person      float64
# from_this_person_to_poi      float64
# loan_advances                float64
# long_term_incentive          float64
# other                        float64
# restricted_stock             float64
# restricted_stock_deferred    float64
# salary                       float64
# shared_receipt_with_poi      float64
# to_messages                  float64
# total_payments               float64
# total_stock_value            float64
# dtype: object
#
# numbers of NaN:
# bonus                         62
# deferral_payments             96
# deferred_income               87
# director_fees                115
# exercised_stock_options       42
# expenses                      49
# from_messages                 56
# from_poi_to_this_person       56
# from_this_person_to_poi       56
# loan_advances                129
# long_term_incentive           75
# other                         52
# restricted_stock              34
# restricted_stock_deferred    115
# salary                        49
# shared_receipt_with_poi       56
# to_messages                   56
# total_payments                20
# total_stock_value             18
# dtype: int64
#
# numbers of nunique:
# bonus                         34
# deferral_payments             36
# deferred_income               42
# director_fees                 17
# exercised_stock_options       89
# expenses                      82
# from_messages                 56
# from_poi_to_this_person       49
# from_this_person_to_poi       34
# loan_advances                  3
# long_term_incentive           47
# other                         79
# restricted_stock              86
# restricted_stock_deferred     17
# salary                        82
# shared_receipt_with_poi       73
# to_messages                   76
# total_payments               112
# total_stock_value            112
# dtype: int64

# %%
# 觀察特徵值
f, ax = plt.subplots(5,4, figsize=(25, 30))
sns.distplot(X['bonus'].dropna(), ax = ax[0, 0])
sns.distplot(X['deferral_payments'].dropna(), ax = ax[0, 1])
sns.distplot(X['deferred_income'].dropna(), ax = ax[0, 2])
sns.distplot(X['director_fees'].dropna(), ax = ax[0, 3])
sns.distplot(X['exercised_stock_options'].dropna(), ax = ax[1, 0])
sns.distplot(X['expenses'].dropna(), ax = ax[1, 1])
sns.distplot(X['from_messages'].dropna(), ax = ax[1, 2])
sns.distplot(X['from_poi_to_this_person'].dropna(), ax = ax[1, 3])
sns.distplot(X['from_this_person_to_poi'].dropna(), ax = ax[2, 0])
sns.distplot(X['loan_advances'].dropna(), ax = ax[2, 1])
sns.distplot(X['long_term_incentive'].dropna(), ax = ax[2, 2])
sns.distplot(X['other'].dropna(), ax = ax[2, 3])
sns.distplot(X['restricted_stock'].dropna(), ax = ax[3, 0])
sns.distplot(X['restricted_stock_deferred'].dropna(), ax = ax[3, 1])
sns.distplot(X['salary'].dropna(), ax = ax[3, 2])
sns.distplot(X['shared_receipt_with_poi'].dropna(), ax = ax[3, 3])
sns.distplot(X['to_messages'].dropna(), ax = ax[4, 0])
sns.distplot(X['total_payments'].dropna(), ax = ax[4, 1])
sns.distplot(X['total_stock_value'].dropna(), ax = ax[4, 2])

ax[0,0].set_title('bonus', fontsize = 30)
ax[0,1].set_title('deferral_payments', fontsize = 30)
ax[0,2].set_title('deferred_income', fontsize = 30)
ax[0,3].set_title('director_fees', fontsize = 30)
ax[1,0].set_title('exercised_stock_options', fontsize = 30)
ax[1,1].set_title('expenses', fontsize = 30)
ax[1,2].set_title('from_messages', fontsize = 30)
ax[1,3].set_title('from_poi_to_this_person', fontsize = 30)
ax[2,0].set_title('from_this_person_to_poi', fontsize = 30)
ax[2,1].set_title('loan_advances', fontsize = 30)
ax[2,2].set_title('long_term_incentive', fontsize = 30)
ax[2,3].set_title('other', fontsize = 30)
ax[3,0].set_title('restricted_stock', fontsize = 30)
ax[3,1].set_title('restricted_stock_deferred', fontsize = 30)
ax[3,2].set_title('salary', fontsize = 30)
ax[3,3].set_title('shared_receipt_with_poi', fontsize = 30)
ax[4,0].set_title('to_messages', fontsize = 30)
ax[4,1].set_title('total_payments', fontsize = 30)
ax[4,2].set_title('total_stock_value', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'total_stock_value')

# %%
# 在這邊觀察到'restricted_stock_deferred'有正的值，推測應該是忘記輸入負號，所以先將他修正
X.loc[X['restricted_stock_deferred'] > 0, 'restricted_stock_deferred'] *= -1.0

# %%
# 剩下的修正離群值
for col in X.columns:
    Q1 = X.loc[X[col].notna(), col].quantile(0.25)
    Q3 = X.loc[X[col].notna(), col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    X.loc[X[col].notna(), col] = X.loc[(X[col].notna()), col].clip(lower, upper)

# 由上圖可以知道除了'loan_advances'以外的特徵都為偏態
features_Skewness = ['bonus', 'deferral_payments', 'deferred_income', 'director_fees', 'exercised_stock_options', 
                     'expenses', 'from_messages', 'from_poi_to_this_person', 'from_this_person_to_poi', 
                     'long_term_incentive', 'other', 'restricted_stock', 'restricted_stock_deferred', 'salary', 
                     'shared_receipt_with_poi', 'to_messages', 'total_payments', 'total_stock_value']

# 去除偏態 將數據做平滑處理
for col in X.columns:
    if col in features_Skewness and col in ['deferred_income', 'restricted_stock_deferred']:
        X.loc[X[col].notna(), col] = -1.0 * np.log1p(-1.0 * X.loc[X[col].notna(), col])
    elif col in features_Skewness:
        X.loc[X[col].notna(), col] = np.log1p(X.loc[X[col].notna(), col])

# %%
# 觀察修改後的特徵值
f, ax = plt.subplots(5,4, figsize=(25, 30))
sns.distplot(X['bonus'].dropna(), ax = ax[0, 0])
sns.distplot(X['deferral_payments'].dropna(), ax = ax[0, 1])
sns.distplot(X['deferred_income'].dropna(), ax = ax[0, 2])
sns.distplot(X['director_fees'].dropna(), ax = ax[0, 3])
sns.distplot(X['exercised_stock_options'].dropna(), ax = ax[1, 0])
sns.distplot(X['expenses'].dropna(), ax = ax[1, 1])
sns.distplot(X['from_messages'].dropna(), ax = ax[1, 2])
sns.distplot(X['from_poi_to_this_person'].dropna(), ax = ax[1, 3])
sns.distplot(X['from_this_person_to_poi'].dropna(), ax = ax[2, 0])
sns.distplot(X['loan_advances'].dropna(), ax = ax[2, 1])
sns.distplot(X['long_term_incentive'].dropna(), ax = ax[2, 2])
sns.distplot(X['other'].dropna(), ax = ax[2, 3])
sns.distplot(X['restricted_stock'].dropna(), ax = ax[3, 0])
sns.distplot(X['restricted_stock_deferred'].dropna(), ax = ax[3, 1])
sns.distplot(X['salary'].dropna(), ax = ax[3, 2])
sns.distplot(X['shared_receipt_with_poi'].dropna(), ax = ax[3, 3])
sns.distplot(X['to_messages'].dropna(), ax = ax[4, 0])
sns.distplot(X['total_payments'].dropna(), ax = ax[4, 1])
sns.distplot(X['total_stock_value'].dropna(), ax = ax[4, 2])

ax[0,0].set_title('bonus', fontsize = 30)
ax[0,1].set_title('deferral_payments', fontsize = 30)
ax[0,2].set_title('deferred_income', fontsize = 30)
ax[0,3].set_title('director_fees', fontsize = 30)
ax[1,0].set_title('exercised_stock_options', fontsize = 30)
ax[1,1].set_title('expenses', fontsize = 30)
ax[1,2].set_title('from_messages', fontsize = 30)
ax[1,3].set_title('from_poi_to_this_person', fontsize = 30)
ax[2,0].set_title('from_this_person_to_poi', fontsize = 30)
ax[2,1].set_title('loan_advances', fontsize = 30)
ax[2,2].set_title('long_term_incentive', fontsize = 30)
ax[2,3].set_title('other', fontsize = 30)
ax[3,0].set_title('restricted_stock', fontsize = 30)
ax[3,1].set_title('restricted_stock_deferred', fontsize = 30)
ax[3,2].set_title('salary', fontsize = 30)
ax[3,3].set_title('shared_receipt_with_poi', fontsize = 30)
ax[4,0].set_title('to_messages', fontsize = 30)
ax[4,1].set_title('total_payments', fontsize = 30)
ax[4,2].set_title('total_stock_value', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'total_stock_value')

# %% [markdown]
# #### 缺失值 Missing value
# - 發現部分特徵都缺少0這個值, 因此我判斷nan就是0
# - 'from_poi_to_this_person','from_this_person_to_poi'這兩個都有0, 因此我用平均值+-標準差來補

# %%
# 先取得都是 nan 沒有 0 的特徵陣列
features_NaN_to_0 = ['bonus', 'deferral_payments', 'deferred_income', 'director_fees', 'exercised_stock_options', 
                     'expenses', 'from_messages', 'loan_advances', 'long_term_incentive', 'other', 
                     'restricted_stock', 'restricted_stock_deferred', 'salary', 'shared_receipt_with_poi', 
                     'to_messages', 'total_payments', 'total_stock_value']

# 再取得需特殊處理的特徵: from_poi_to_this_person
average_from_poi_to_this_person = X['from_poi_to_this_person'].mean()
std_from_poi_to_this_person = X['from_poi_to_this_person'].std()
nan_count_from_poi_to_this_person = X['from_poi_to_this_person'].isnull().sum()
random_from_poi = np.random.RandomState(42).randint(
                 average_from_poi_to_this_person - std_from_poi_to_this_person, 
                 average_from_poi_to_this_person + std_from_poi_to_this_person, 
                 size = nan_count_from_poi_to_this_person)

# 再取得需特殊處理的特徵: from_this_person_to_poi
average_from_this_person_to_poi = X['from_this_person_to_poi'].mean()
std_from_this_person_to_poi = X['from_this_person_to_poi'].std()
nan_count_from_this_person_to_poi = X['from_this_person_to_poi'].isnull().sum()
random_to_poi = np.random.RandomState(42).randint(
                 average_from_this_person_to_poi - std_from_this_person_to_poi, 
                 average_from_this_person_to_poi + std_from_this_person_to_poi, 
                 size = nan_count_from_this_person_to_poi)

# 填補缺失值
for column in X.columns:
    if column in features_NaN_to_0:
        X[column] = X[column].fillna(0)
    elif column == 'from_poi_to_this_person':
        X.loc[np.isnan(X[column]), column] = random_from_poi
    elif column == 'from_this_person_to_poi':
        X.loc[np.isnan(X[column]), column] = random_to_poi

# %% [markdown]
# ## 特徵工程
# >1. 特徵建構: 從原始數據中人工的構建新的特徵，取代原始數據的特徵
# >2. 特徵提取: 將機器學習演算法不能識別的原始數據，轉化為演算法可以識別的特徵
#     - 特徵提取的首要任務是將變數從文字轉換成數字，連續數值轉為離散數值，以利統計與導入演算法模型
# >3. 特徵選擇: 從所有的特徵中選擇一組最好的特徵集，捨去無關的特徵，保留相關性高的特徵
#     - 使用相關性作圖(Pearson相關係數)，顏色較淺的部分為沒有關係的，顏色偏藍就是正相關，顏色偏紅就是負相關，而我們在意的是與poi有相關性無論正負，若是值越接近0，即是要被剃除的特徵。

# %%
# 觀察是否為犯罪者在各特徵上之表現差異來給我們一些特徵建構的想法
X_train = X[:train_data.shape[0]]
X_train['poi'] = y_train
X_test = X[train_data.shape[0]:]
X_train_value = X_train.groupby(['poi'])
X_train_value.mean()
# Out:
#            bonus  deferral_payments  deferred_income  director_fees  \
# poi
# False   6.063338           2.928539        -3.165712       1.683502
# True   10.813517           3.173888        -5.834355       0.000000
#
#        exercised_stock_options   expenses  from_messages  \
# poi
# False                 9.438182   5.764452       2.110936
# True                  8.566921  10.891619       2.375837
#
#        from_poi_to_this_person  from_this_person_to_poi  loan_advances  \
# poi
# False                 2.422321                 1.344366    4494.382022
# True                  3.393225                 2.301169       0.000000
#
#        long_term_incentive      other  restricted_stock  \
# poi
# False             5.061195   4.905839          8.864044
# True              6.404468  10.923960         12.105512
#
#        restricted_stock_deferred     salary  shared_receipt_with_poi  \
# poi
# False                  -1.212463   7.182144                 3.172996
# True                    0.000000  11.202666                 4.088633
#
#        to_messages  total_payments  total_stock_value
# poi
# False     3.676189       10.671608          11.508365
# True      4.249393       13.898521          14.154684

# %% [markdown]
# #### 1. 特徵建構

# %%
# 將薪水與股票價值加總
train_data['total_incomes']= train_data['total_payments'] + train_data['total_stock_value']

# 將延期薪水與延期股票加總
train_data['total_deferred']= train_data['deferred_income'] + train_data['restricted_stock_deferred']

# 計算薪資總額
train_data['total_payments_recount'] = train_data['deferred_income'] + train_data['bonus'] + train_data['deferral_payments'] + train_data['director_fees'] + train_data['expenses'] + train_data['loan_advances'] + train_data['long_term_incentive']+ train_data['other'] +train_data['salary']
    
# 計算薪資總額誤差: 我自己算的跟資料集給的出現誤差, 表示有人作假帳 
train_data['total_payments_error'] = train_data['total_payments_recount'] - train_data['total_payments']

# 計算股票總和 
train_data['total_stock_value_recount'] = train_data['restricted_stock_deferred'] + train_data['exercised_stock_options'] + train_data['restricted_stock']

# 計算股票總和誤差
train_data['total_stock_value_error'] = train_data['total_stock_value_recount'] - train_data['total_stock_value']

# 計算email相關的總和
## 與犯罪者有關
train_data['total_poi_contact'] = train_data['from_poi_to_this_person'] + train_data['from_this_person_to_poi']
## 一般通聯記錄
train_data['total_messages'] = train_data['from_messages'] + train_data['to_messages']

# 計算與犯罪者聯絡的密集度與一般聯絡的比例
## 收到郵件之比例
train_data['from_poi_contact_rate'] = train_data['from_poi_to_this_person'] / (1.0 + train_data['from_poi_to_this_person'] + train_data['from_messages'])
## 寄出郵件之比例
train_data['to_poi_contact_rate'] = train_data['from_this_person_to_poi'] / (1.0 + train_data['from_this_person_to_poi'] + train_data['to_messages'])

# %% [markdown]
# #### 2. 特徵提取

# %%
# 觀察資料分布
X.describe()
# Out:
#             bonus  deferral_payments  deferred_income  director_fees  \
# count  132.000000         132.000000       132.000000     132.000000
# mean     7.078953           3.310068        -3.979383       1.486512
# std      6.708513           5.592070         5.660010       3.881601
# min      0.000000           0.000000       -14.139405       0.000000
# 25%      0.000000           0.000000       -10.520832       0.000000
# 50%     12.206078           0.000000         0.000000       0.000000
# 75%     13.527830           9.356100         0.000000       0.000000
# max     14.457365          14.514987         0.000000      11.822504
#
#        exercised_stock_options    expenses  from_messages  \
# count               132.000000  132.000000     132.000000
# mean                  9.319244    6.517646       2.202515
# std                   6.498955    5.142438       2.011797
# min                   0.000000    0.000000       0.000000
# 25%                   0.000000    0.000000       0.000000
# 50%                  13.122531    9.736859       2.833213
# 75%                  14.300007   10.884218       3.812157
# max                  15.391673   12.019510       5.201256
#
#        from_poi_to_this_person  from_this_person_to_poi  loan_advances  \
# count               132.000000               132.000000   1.320000e+02
# mean                  2.591125                 1.508532   6.539773e+05
# std                   1.382825                 1.248335   7.305290e+06
# min                   0.000000                 0.000000   0.000000e+00
# 25%                   2.000000                 0.000000   0.000000e+00
# 50%                   3.000000                 1.497866   0.000000e+00
# 75%                   3.583519                 2.269145   0.000000e+00
# max                   4.875197                 3.842137   8.392500e+07
#
#        long_term_incentive       other  restricted_stock  \
# count           132.000000  132.000000        132.000000
# mean              5.570278    5.963436          9.566009
# std               6.437333    5.393222          5.824938
# min               0.000000    0.000000          0.000000
# 25%               0.000000    0.000000          0.000000
# 50%               0.000000    6.655437         12.660547
# 75%              12.776610   11.851682         13.309321
# max              14.117738   13.710187         14.502111
#
#        restricted_stock_deferred      salary  shared_receipt_with_poi  \
# count                 132.000000  132.000000               132.000000
# mean                   -1.578651    7.777723                 3.499280
# std                     4.141584    6.006580                 3.253695
# min                   -13.871180    0.000000                 0.000000
# 25%                     0.000000    0.000000                 0.000000
# 50%                     0.000000   12.178362                 4.177102
# 75%                     0.000000   12.478750                 6.607662
# max                     0.000000   12.912977                 8.148663
#
#        to_messages  total_payments  total_stock_value
# count   132.000000      132.000000         132.000000
# mean      3.921153       11.286458          11.824827
# std       3.475830        5.096516           4.993436
# min       0.000000        0.000000           0.000000
# 25%       0.000000       11.371363          12.247063
# 50%       5.435787       13.682922          13.696938
# 75%       7.138081       14.324342          14.538163
# max       8.478270       15.296202          15.458045

# %%
# 將這些數值特徵分成五等分，精簡模型的數值分析，並做 LabelEncoder
for column in X.columns:
    X[column] = pd.cut(X[column], 5)
    X[column] = LabelEncoder().fit_transform(X[column])
X.head(10)
# Out:
#    bonus  deferral_payments  deferred_income  director_fees  \
# 0      2                  0                2              0
# 1      2                  0                3              0
# 2      2                  0                0              0
# 3      0                  1                3              0
# 4      0                  0                3              0
# 5      2                  1                0              0
# 6      2                  0                3              0
# 7      2                  0                3              0
# 8      2                  2                0              0
# 9      2                  0                0              0
#
#    exercised_stock_options  expenses  from_messages  from_poi_to_this_person  \
# 0                        3         3              2                        2
# 1                        0         3              0                        3
# 2                        0         3              3                        4
# 3                        3         3              0                        1
# 4                        3         3              0                        3
# 5                        0         3              2                        4
# 6                        3         3              1                        4
# 7                        3         3              2                        4
# 8                        3         3              3                        3
# 9                        0         3              0                        3
#
#    from_this_person_to_poi  loan_advances  long_term_incentive  other  \
# 0                        3              0                    0      4
# 1                        2              0                    2      4
# 2                        4              0                    2      2
# 3                        0              0                    0      2
# 4                        2              0                    0      4
# 5                        3              0                    0      4
# 6                        2              0                    1      4
# 7                        3              0                    2      4
# 8                        4              0                    0      2
# 9                        2              0                    2      4
#
#    restricted_stock  restricted_stock_deferred  salary  \
# 0                 2                          2       1
# 1                 2                          2       1
# 2                 2                          2       1
# 3                 0                          2       0
# 4                 2                          2       1
# 5                 2                          2       1
# 6                 2                          2       1
# 7                 2                          2       1
# 8                 2                          2       1
# 9                 2                          2       1
#
#    shared_receipt_with_poi  to_messages  total_payments  total_stock_value
# 0                        2            2               4                  2
# 1                        0            0               4                  2
# 2                        4            3               4                  1
# 3                        0            0               3                  2
# 4                        0            0               4                  2
# 5                        4            3               4                  2
# 6                        4            2               4                  2
# 7                        4            3               4                  2
# 8                        4            3               4                  2
# 9                        0            0               4                  2

# %% [markdown]
# #### 3.特徵選擇
# - 使用皮爾遜積差相關係數來做特徵選擇

# %%
# 因為剛剛把 poi 移除了, 所以先加回來判斷相關係數
X_train = X[:train_data.shape[0]]
train = pd.concat([X_train, pd.DataFrame(y_train)], axis = 1)

# 先建立空圖
colormap = plt.cm.RdBu
plt.figure(figsize = (30, 30))
plt.title('Pearson Correlation of Features', y = 1.01, size = 50)

# 再將資料加入圖中
sns.heatmap(train.astype(float).corr(), linewidths = 0.1, vmin = -1.0 ,vmax = 1.0, square = True, cmap = colormap, 
            linecolor = 'white', annot = True, xticklabels = True, yticklabels = True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
# 觀察相關性
train.astype(float).corr()['poi']
# Out:
# bonus                        0.213545
# deferral_payments            0.002760
# deferred_income             -0.151719
# director_fees               -0.130325
# exercised_stock_options     -0.034882
# expenses                     0.317134
# from_messages                0.051794
# from_poi_to_this_person      0.225486
# from_this_person_to_poi      0.254684
# loan_advances                     NaN
# long_term_incentive          0.035103
# other                        0.344915
# restricted_stock             0.153828
# restricted_stock_deferred    0.102949
# salary                       0.195639
# shared_receipt_with_poi      0.106684
# to_messages                  0.066351
# total_payments               0.181742
# total_stock_value            0.145265
# poi                          1.000000
# Name: poi, dtype: float64

# %%
# 取得相關性絕對值大於 0.2 的特徵
feature_select = []
for i in range(len(train.astype(float).corr()['poi'])):
    if abs(train.astype(float).corr()['poi'].values[i] >= 0.20):
        feature_select.append(train.astype(float).corr()['poi'].index[i])

# 刪除較不相關的欄位
for column in X.columns:
    if column not in feature_select:
        X = X.drop([column], axis = 1)
        
# 觀察修正後的訓練資料尺寸
print(f'X shape: {X.shape}')
# Out:
# X shape: (132, 5)

# %% [markdown]
# ## 建立模型
# - 建立需要用到的模型, 再利用交叉驗證判斷好壞

# %%
X_train = X[:train_data.shape[0]]
y_train = np.ravel(y_train)
X_test = X[train_data.shape[0]:]
print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}')
# Out:
# X_train shape: (99, 5)
# y_train shape: (99,)
# X_test shape: (33, 5)

# %%
mm = MinMaxScaler().fit(X_train)
X_train_mm = mm.transform(X_train)
X_test_mm = mm.transform(X_test)

# %% [markdown]
# ### 訓練模型

# %%
rf = RandomForestRegressor(n_estimators=300, min_samples_split=9, min_samples_leaf=10, 
                           max_features='sqrt', max_depth=8, bootstrap=False)

# XGBoost
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# LightGBM
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %%
rf.fit(X_train_mm, y_train)
rf_pred = np.expm1(rf.predict(X_test_mm))

model_xgb.fit(X_train_mm, y_train)
xgb_pred = np.expm1(model_xgb.predict(X_test_mm))

model_lgb.fit(X_train_mm, y_train)
lgb_pred = np.expm1(model_lgb.predict(X_test_mm))

# 混合泛化預測檔 (依 Kaggle 傳回分數調整比重, 越準確者比重越高, 依資料性質有所不同)
blending_pred = rf_pred*0.25 + xgb_pred*0.15 + lgb_pred*0.6
# Out:
# [17:49:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5

# %% [markdown]
# ### 測試模型並輸出

# %%
sub = pd.read_csv('./data/Enron Fraud/sample_submission.csv')
submission = pd.DataFrame()
submission['name'] = sub['name']
submission['poi'] = blending_pred 
submission.to_csv('submission_blending.csv', index = False)
